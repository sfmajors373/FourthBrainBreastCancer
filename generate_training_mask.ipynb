# %%
import matplotlib.pyplot as plt 
import numpy as np
# import math
from preprocessing.datamodel import SlideManager #, Slide
from preprocessing.processing import generator_live_tiles, rgb2gray, apply_image_filters #, get_otsu_threshold #apply_image_filters, remove_alpha_channel, rgb2gray, create_tumor_mask, ProgressBar, create_otsu_mask_by_threshold, generate_testing_slide
# from generate_tiles import get_otsu_threshold
# from preprocessing.histopath import pil_to_np_rgb, np_to_pil, mask_rgb
from skimage.filters import threshold_otsu

# %%
CAM_BASE_DIR = '/home/sarah/ForthBrainCancer-Dataset/'
CAM16_DIR = CAM_BASE_DIR + 'CAMELYON16/'
GENERATED_DATA = CAM_BASE_DIR + 'training_CAMELYON16/'

# %%
mgr = SlideManager(cam16_dir=CAM16_DIR)
# Out:
# dict_items([('normal_063.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_063.tif'), ('normal_147.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_147.tif'), ('normal_018.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_018.tif'), ('normal_140.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_140.tif'), ('normal_064.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_064.tif'), ('normal_016.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_016.tif'), ('normal_132.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_132.tif'), ('normal_135.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_135.tif'), ('normal_011.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_011.tif'), ('normal_149.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_149.tif'), ('normal_089.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_089.tif'), ('normal_100.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_100.tif'), ('normal_024.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_024.tif'), ('normal_023.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_023.tif'), ('normal_107.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_107.tif'), ('normal_080.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_080.tif'), ('normal_051.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_051.tif'), ('normal_109.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_109.tif'), ('normal_087.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_087.tif'), ('normal_056.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_056.tif'), ('normal_047.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_047.tif'), ('normal_096.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_096.tif'), ('normal_118.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_118.tif'), ('normal_040.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_040.tif'), ('normal_091.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_091.tif'), ('normal_032.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_032.tif'), ('normal_116.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_116.tif'), ('normal_111.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_111.tif'), ('normal_049.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_049.tif'), ('normal_098.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_098.tif'), ('normal_035.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_035.tif'), ('normal_124.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_124.tif'), ('normal_158.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_158.tif'), ('normal_007.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_007.tif'), ('normal_123.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_123.tif'), ('normal_151.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_151.tif'), ('normal_009.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_009.tif'), ('normal_075.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_075.tif'), ('normal_072.tif', '/home/sarah/ForthBrainCancer-Dataset/CAMELYON16/training/normal/normal_072.tif'), ('normal_1 ...

# %%
i = 2
level = 4
tile_size=256
overlap = 0
verbose = True
poi = 0.5

# %%
slide = mgr.negative_slides[i]

# %%
# load the slide into numpy array
arr = np.asarray(slide.get_full_slide(level=level))

# %%
# convert it to gray scale
arr_gray = rgb2gray(arr)
# calculate otsu threshold
threshold = threshold_otsu(arr_gray)

# %%
slide.get_thumbnail((300, 300))  # openslide method
# Out:
# <PIL.Image.Image image mode=RGB size=133x300 at 0x7FB1CCFE44C0>

# %%
mask_filters = apply_image_filters(arr, remove_object_size=5000, remove_holes_size=3000)
# Out:
# Remove Small Objs    | Time: 0:00:01.149680  Type: bool    Shape: (13824, 6112)
# Remove Small Holes   | Time: 0:00:01.447711  Type: bool    Shape: (13824, 6112)

# %%
plt.imshow(mask_filters)

# %%
# create a new and unconsumed tile iterator
# because we have so many  negative slides we do not use overlap
iter_explore_tiles = generator_live_tiles(slide, level, threshold, poi, tile_size, overlap, verbose=False)

# %%
v = list()
for a, b, c, d  in iter_explore_tiles:
    v.append([a, b, c, d])
# Out:
# File not accessible

# %%
plt.imshow(v[0][0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(v[0][1])
