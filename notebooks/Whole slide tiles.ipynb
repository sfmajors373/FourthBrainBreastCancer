# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
import sys  
sys.path.insert(0, '..')

# %%
from tiling.preprocessing.datamodel import SlideManager, Slide

from tiling.preprocessing.processing import remove_alpha_channel, get_otsu_threshold, rgb2gray, apply_image_filters, create_tumor_mask, split_whole_slide, split_test_slide

# %%
CAM_BASE_DIR = '/media/nico/data/fourthbrain/project/'
CAM16_DIR = CAM_BASE_DIR + 'CAMELYON16/'

# %%
color_normalization_json = "../tiling/CAMELYON16_color_normalization.json"

# %%
mgr = SlideManager(cam16_dir=CAM16_DIR)

# %%
i = 0
level = 3
tile_size=256
verbose = True

# %%
slide = mgr.test_slides[i]

# %%
slide.get_thumbnail((300, 300))  # openslide method
# Out:
# <PIL.Image.Image image mode=RGB size=288x300 at 0x7FD11012DF90>

# %%
tumor_mask = create_tumor_mask(slide, level=level)

# %%
plt.imshow(tumor_mask)

# %%
iter_whole = split_whole_slide(slide, level=level, tile_size=tile_size, color_normalization_file=color_normalization_json, verbose=False)

# %%
tiles, labels, coords, slide_locations = list(), list(), list(), list()
for tile, label, coord, slide_location in iter_whole:
    tiles.append(tile)
    labels.append(label)
    coords.append(coord)
    slide_locations.append(slide_location)

# %%
plt.imshow(tiles[200])
labels[200]
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 1
